# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#reading the dataset
dataset=pd.read_csv("Boom Bike.csv")

# %%
dataset.head(5)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dataset.shape
# Out:
# (730, 16)

# %%
dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
# assigning string values to different seasons instead of numeric values
# 1 = spring
dataset.loc[(dataset['season'] == 1), 'season'] = 'spring'

# 2 = summer
dataset.loc[(dataset['season'] == 2), 'season'] = 'summer'

# 3 = fall
dataset.loc[(dataset['season'] == 3), 'season'] = 'fall'

# 4 = winter
dataset.loc[(dataset['season'] == 4), 'season'] = 'winter'

# %%
dataset['season'].astype('category').value_counts()
# Out:
# season
# fall      188
# summer    184
# spring    180
# winter    178
# Name: count, dtype: int64

# %%
# 0 = 2018 ,1 =2019 : year
dataset['yr'].astype('category').value_counts()
# Out:
# yr
# 0    365
# 1    365
# Name: count, dtype: int64

# %%
# assigning string values to different months instead of numeric values
def object_map_mnths(x):
    return x.map({1:'Jan',2:'Feb',3:'Mar',4: 'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})

# %%
dataset[['mnth']]=dataset[['mnth']].apply(object_map_mnths)

# %%
dataset.head()
# Out:
#    instant      dteday  season  yr mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018  spring   0  Jan        0        6           0
# 1        2  02-01-2018  spring   0  Jan        0        0           0
# 2        3  03-01-2018  spring   0  Jan        0        1           1
# 3        4  04-01-2018  spring   0  Jan        0        2           1
# 4        5  05-01-2018  spring   0  Jan        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dataset['mnth'].astype('category').value_counts()
# Out:
# mnth
# Aug    62
# Dec    62
# Jan    62
# Jul    62
# Mar    62
# May    62
# Oct    62
# Apr    60
# Jun    60
# Nov    60
# Sep    60
# Feb    56
# Name: count, dtype: int64

# %%
dataset['holiday'].astype('category').value_counts()
# Out:
# holiday
# 0    709
# 1     21
# Name: count, dtype: int64

# %%
def str_map_weekday(x):
    return x.map({1: 'Mon', 2: 'Tues', 3: 'Wed', 4: 'Thurs', 5: 'Fri', 6: 'Sat', 0: 'Sun'})

# %%
dataset[['weekday']]=dataset[['weekday']].apply(str_map_weekday)

# %%
dataset['weekday'].astype('category').value_counts()
# Out:
# weekday
# Mon      105
# Sat      105
# Sun      105
# Fri      104
# Thurs    104
# Tues     104
# Wed      103
# Name: count, dtype: int64

# %%
dataset['workingday'].astype('category').value_counts()
# Out:
# workingday
# 1    499
# 0    231
# Name: count, dtype: int64

# %%
# 1 = Clear,few clouds,Partly Cloudly
dataset.loc[(dataset['weathersit'] == 1), 'weathersit'] = 'A'

# 2 = Mist, Cloudly
dataset.loc[(dataset['weathersit'] == 2), 'weathersit'] = 'B'

# 3 = Light Snow,Heavy Rain
dataset.loc[(dataset['weathersit'] == 3), 'weathersit'] = 'C'

# %%
dataset['weathersit'].astype('category').value_counts()
# Out:
# weathersit
# A    463
# B    246
# C     21
# Name: count, dtype: int64

# %%
#importing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#temperature
sns.displot(dataset['temp'])

# %%
#actual temperature
sns.displot(dataset['atemp'])
plt.show()

# %%
#wind speed
sns.displot(dataset['windspeed'])
plt.show()

# %%
# target variable: count of total rental bikes includes both casual and registered
sns.displot(dataset['cnt'])
plt.show()

# %%
# converting date to datetime format
dataset['dteday']=dataset['dteday'].astype('datetime64[ns]')

# %%
dataset_categorical=dataset.select_dtypes(exclude=['float64','datetime64','int64'])

# %%
dataset_categorical.columns
# Out:
# Index(['season', 'mnth', 'weekday', 'weathersit'], dtype='object')

# %%
dataset_categorical
# Out:
#      season mnth weekday weathersit
# 0    spring  Jan     Sat          B
# 1    spring  Jan     Sun          B
# 2    spring  Jan     Mon          A
# 3    spring  Jan    Tues          A
# 4    spring  Jan     Wed          A
# ..      ...  ...     ...        ...
# 725  spring  Dec   Thurs          B
# 726  spring  Dec     Fri          B
# 727  spring  Dec     Sat          B
# 728  spring  Dec     Sun          A
# 729  spring  Dec     Mon          B
#
# [730 rows x 4 columns]

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,3,1)
sns.boxplot(x='season',y='cnt',data=dataset)
plt.subplot(3,3,2)
sns.boxplot(x='mnth',y='cnt',data=dataset)
plt.subplot(3,3,3)
sns.boxplot(x='weekday',y='cnt',data=dataset)
plt.subplot(3,3,4)
sns.boxplot(x='weathersit',y='cnt',data=dataset)
plt.subplot(3,3,5)
sns.boxplot(x='workingday',y='cnt',data=dataset)
plt.subplot(3,3,6)
sns.boxplot(x='yr',y='cnt',data=dataset)
plt.subplot(3,3,7)
sns.boxplot(x='holiday',y='cnt',data=dataset)
plt.show()

# %%
intvarlist=["casual","registered","cnt"]

for var in intvarlist:
    dataset[var]=dataset[var].astype("float")

# %%
dataset_numeric=dataset.select_dtypes(include=['float64'])
dataset_numeric.head()
# Out:
#         temp     atemp      hum  windspeed  casual  registered     cnt
# 0  14.110847  18.18125  80.5833  10.749882   331.0       654.0   985.0
# 1  14.902598  17.68695  69.6087  16.652113   131.0       670.0   801.0
# 2   8.050924   9.47025  43.7273  16.636703   120.0      1229.0  1349.0
# 3   8.200000  10.60610  59.0435  10.739832   108.0      1454.0  1562.0
# 4   9.305237  11.46350  43.6957  12.522300    82.0      1518.0  1600.0

# %%
sns.pairplot(dataset_numeric)
plt.show()

# %%
cor=dataset_numeric.corr()
cor
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.991696  0.128565  -0.158186  0.542731    0.539436
# atemp       0.991696  1.000000  0.141512  -0.183876  0.543362    0.543678
# hum         0.128565  0.141512  1.000000  -0.248506 -0.075211   -0.089212
# windspeed  -0.158186 -0.183876 -0.248506   1.000000 -0.167995   -0.217914
# casual      0.542731  0.543362 -0.075211  -0.167995  1.000000    0.394137
# registered  0.539436  0.543678 -0.089212  -0.217914  0.394137    1.000000
# cnt         0.627044  0.630685 -0.098543  -0.235132  0.672123    0.945411
#
#                  cnt
# temp        0.627044
# atemp       0.630685
# hum        -0.098543
# windspeed  -0.235132
# casual      0.672123
# registered  0.945411
# cnt         1.000000

# %%
# heatmap
mask=np.array(cor)
mask[np.tril_indices_from(mask)]=False
fig,ax=plt.subplots()
fig.set_size_inches(10,10)
sns.heatmap(cor,mask=mask,vmax=0.8,square=True,annot=True)
# Out:
# <Axes: >

# %%
# removing atemp as it is highly corealed with temp
dataset.drop('atemp',axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    instant     dteday  season  yr mnth  holiday weekday  workingday  \
# 0        1 2018-01-01  spring   0  Jan        0     Sat           0
# 1        2 2018-02-01  spring   0  Jan        0     Sun           0
# 2        3 2018-03-01  spring   0  Jan        0     Mon           1
# 3        4 2018-04-01  spring   0  Jan        0    Tues           1
# 4        5 2018-05-01  spring   0  Jan        0     Wed           1
#
#   weathersit       temp      hum  windspeed  casual  registered     cnt
# 0          B  14.110847  80.5833  10.749882   331.0       654.0   985.0
# 1          B  14.902598  69.6087  16.652113   131.0       670.0   801.0
# 2          A   8.050924  43.7273  16.636703   120.0      1229.0  1349.0
# 3          A   8.200000  59.0435  10.739832   108.0      1454.0  1562.0
# 4          A   9.305237  43.6957  12.522300    82.0      1518.0  1600.0

# %%
dataset_categorical=dataset.select_dtypes(include=['object'])

# %%
dataset_categorical.head()
# Out:
#    season mnth weekday weathersit
# 0  spring  Jan     Sat          B
# 1  spring  Jan     Sun          B
# 2  spring  Jan     Mon          A
# 3  spring  Jan    Tues          A
# 4  spring  Jan     Wed          A

# %%
dataset_dummies=pd.get_dummies(dataset_categorical,drop_first=True)
dataset_dummies.head()
# Out:
#    season_spring  season_summer  season_winter  mnth_Aug  mnth_Dec  mnth_Feb  \
# 0           True          False          False     False     False     False
# 1           True          False          False     False     False     False
# 2           True          False          False     False     False     False
# 3           True          False          False     False     False     False
# 4           True          False          False     False     False     False
#
#    mnth_Jan  mnth_Jul  mnth_Jun  mnth_Mar  ...  mnth_Oct  mnth_Sep  \
# 0      True     False     False     False  ...     False     False
# 1      True     False     False     False  ...     False     False
# 2      True     False     False     False  ...     False     False
# 3      True     False     False     False  ...     False     False
# 4      True     False     False     False  ...     False     False
#
#    weekday_Mon  weekday_Sat  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 0        False         True        False          False         False
# 1        False        False         True          False         False
# 2         True        False        False          False         False
# 3        False        False        False          False          True
# 4        False        False        False          False         False
#
#    weekday_Wed  weathersit_B  weathersit_C
# 0        False          True         False
# 1        False          True         False
# 2        False         False         False
# 3        False         False         False
# 4         True         False         False
#
# [5 rows x 22 columns]

# %%
# drop categorical variable columns
dataset=dataset.drop(list(dataset_categorical.columns),axis=1)
dataset
# Out:
#      instant     dteday  yr  holiday  workingday       temp      hum  \
# 0          1 2018-01-01   0        0           0  14.110847  80.5833
# 1          2 2018-02-01   0        0           0  14.902598  69.6087
# 2          3 2018-03-01   0        0           1   8.050924  43.7273
# 3          4 2018-04-01   0        0           1   8.200000  59.0435
# 4          5 2018-05-01   0        0           1   9.305237  43.6957
# ..       ...        ...  ..      ...         ...        ...      ...
# 725      726 2019-12-27   1        0           1  10.420847  65.2917
# 726      727 2019-12-28   1        0           1  10.386653  59.0000
# 727      728 2019-12-29   1        0           0  10.386653  75.2917
# 728      729 2019-12-30   1        0           0  10.489153  48.3333
# 729      730 2019-12-31   1        0           1   8.849153  57.7500
#
#      windspeed  casual  registered     cnt
# 0    10.749882   331.0       654.0   985.0
# 1    16.652113   131.0       670.0   801.0
# 2    16.636703   120.0      1229.0  1349.0
# 3    10.739832   108.0      1454.0  1562.0
# 4    12.522300    82.0      1518.0  1600.0
# ..         ...     ...         ...     ...
# 725  23.458911   247.0      1867.0  2114.0
# 726  10.416557   644.0      2451.0  3095.0
# 727   8.333661   159.0      1182.0  1341.0
# 728  23.500518   364.0      1432.0  1796.0
# 729  10.374682   439.0      2290.0  2729.0
#
# [730 rows x 11 columns]

# %%
# concatenate dummy variables with the dataset
dataset=pd.concat([dataset,dataset_dummies],axis=1)

# %%
dataset.head()
# Out:
#    instant     dteday  yr  holiday  workingday       temp      hum  windspeed  \
# 0        1 2018-01-01   0        0           0  14.110847  80.5833  10.749882
# 1        2 2018-02-01   0        0           0  14.902598  69.6087  16.652113
# 2        3 2018-03-01   0        0           1   8.050924  43.7273  16.636703
# 3        4 2018-04-01   0        0           1   8.200000  59.0435  10.739832
# 4        5 2018-05-01   0        0           1   9.305237  43.6957  12.522300
#
#    casual  registered  ...  mnth_Oct  mnth_Sep  weekday_Mon  weekday_Sat  \
# 0   331.0       654.0  ...     False     False        False         True
# 1   131.0       670.0  ...     False     False        False        False
# 2   120.0      1229.0  ...     False     False         True        False
# 3   108.0      1454.0  ...     False     False        False        False
# 4    82.0      1518.0  ...     False     False        False        False
#
#    weekday_Sun  weekday_Thurs  weekday_Tues  weekday_Wed  weathersit_B  \
# 0        False          False         False        False          True
# 1         True          False         False        False          True
# 2        False          False         False        False         False
# 3        False          False          True        False         False
# 4        False          False         False         True         False
#
#    weathersit_C
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 33 columns]

# %%
dataset=dataset.drop(['instant','dteday'],axis=1,inplace=False)
dataset.head()
# Out:
#    yr  holiday  workingday       temp      hum  windspeed  casual  registered  \
# 0   0        0           0  14.110847  80.5833  10.749882   331.0       654.0
# 1   0        0           0  14.902598  69.6087  16.652113   131.0       670.0
# 2   0        0           1   8.050924  43.7273  16.636703   120.0      1229.0
# 3   0        0           1   8.200000  59.0435  10.739832   108.0      1454.0
# 4   0        0           1   9.305237  43.6957  12.522300    82.0      1518.0
#
#       cnt  season_spring  ...  mnth_Oct  mnth_Sep  weekday_Mon  weekday_Sat  \
# 0   985.0           True  ...     False     False        False         True
# 1   801.0           True  ...     False     False        False        False
# 2  1349.0           True  ...     False     False         True        False
# 3  1562.0           True  ...     False     False        False        False
# 4  1600.0           True  ...     False     False        False        False
#
#    weekday_Sun  weekday_Thurs  weekday_Tues  weekday_Wed  weathersit_B  \
# 0        False          False         False        False          True
# 1         True          False         False        False          True
# 2        False          False         False        False         False
# 3        False          False          True        False         False
# 4        False          False         False         True         False
#
#    weathersit_C
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 31 columns]

# %%
# import libs
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
# split the dataframe into train and test datasets
from sklearn.model_selection import train_test_split
np.random.seed(0)
df_train,df_test=train_test_split(dataset,train_size=0.7,test_size=0.3,random_state=100)

# %%
df_train
# Out:
#      yr  holiday  workingday       temp      hum  windspeed  casual  \
# 653   1        0           1  19.201653  55.8333  12.208807   922.0
# 576   1        0           1  29.246653  70.4167  11.083475   968.0
# 426   1        0           0  16.980847  62.1250  10.792293   956.0
# 728   1        0           0  10.489153  48.3333  23.500518   364.0
# 482   1        0           0  15.443347  48.9583   8.708325  1120.0
# ..   ..      ...         ...        ...      ...        ...     ...
# 526   1        0           1  29.554153  58.7917  13.916771  1017.0
# 578   1        0           1  30.852500  65.9583   8.666718   983.0
# 53    0        0           1   9.091299  42.3043   6.305571   139.0
# 350   0        0           0  10.591653  56.0833  16.292189   275.0
# 79    0        0           1  17.647835  73.7391  19.348461   401.0
#
#      registered     cnt  season_spring  ...  mnth_Oct  mnth_Sep  weekday_Mon  \
# 653      6612.0  7534.0          False  ...      True     False        False
# 576      6248.0  7216.0          False  ...     False     False        False
# 426      3110.0  4066.0           True  ...     False     False        False
# 728      1432.0  1796.0           True  ...     False     False        False
# 482      3100.0  4220.0          False  ...     False     False        False
# ..          ...     ...            ...  ...       ...       ...          ...
# 526      5647.0  6664.0          False  ...     False     False         True
# 578      6278.0  7261.0          False  ...     False     False        False
# 53       1778.0  1917.0           True  ...     False     False        False
# 350      2464.0  2739.0          False  ...     False     False        False
# 79       1676.0  2077.0          False  ...     False     False         True
#
#      weekday_Sat  weekday_Sun  weekday_Thurs  weekday_Tues  weekday_Wed  \
# 653        False        False          False          True        False
# 576        False        False          False          True        False
# 426         True        False          False         False        False
# 728        False         True          False         False        False
# 482         True        False          False         False        False
# ..           ...          ...            ...           ...          ...
# 526        False        False          False         False        False
# 578        False        False           True         False        False
# 53         False        False          False         False         True
# 350         True        False          False         False        False
# 79         False        False          False         False        False
#
#      weathersit_B  weathersit_C
# 653         False         False
# 576         False         False
# 426          True         False
# 728         False         False
# 482          True         False
# ..            ...           ...
# 526          True         False
# 578         False         False
# 53          False         False
# 350          True         False
# 79           True         False
#
# [510 rows x 31 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
# apply scalar to all columns except dummy variables
var = ["temp", "hum", "windspeed", "casual", "registered", "cnt"]
df_train[var] = scaler.fit_transform(df_train[var])

# %%
df_train.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.676471    0.537262    0.650369    0.320768
# std      0.500429    0.157763    0.468282    0.225844    0.145882    0.169797
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.538643    0.199179
# 50%      1.000000    0.000000    1.000000    0.540519    0.653714    0.296763
# 75%      1.000000    0.000000    1.000000    0.735215    0.754830    0.414447
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            casual  registered         cnt
# count  510.000000  510.000000  510.000000
# mean     0.254661    0.523944    0.513620
# std      0.206011    0.228175    0.224593
# min      0.000000    0.000000    0.000000
# 25%      0.094179    0.353487    0.356420
# 50%      0.212740    0.525123    0.518638
# 75%      0.327415    0.696073    0.684710
# max      1.000000    1.000000    1.000000

# %%
# checking the correlation coefficients to see which variables are highly corelated
plt.figure(figsize=(30,30))
sns.heatmap(df_train.corr(),annot=True,cmap="Blues")
plt.show()

# %%
# diving into X and Y
x_train=df_train.drop(["casual","registered"],axis=1)
y_train=df_train.pop('cnt')

# %%
x_train.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed       cnt  \
# 653   1        0           1  0.509887  0.575354   0.300794  0.864243
# 576   1        0           1  0.815169  0.725633   0.264686  0.827658
# 426   1        0           0  0.442393  0.640189   0.255342  0.465255
# 728   1        0           0  0.245101  0.498067   0.663106  0.204096
# 482   1        0           0  0.395666  0.504508   0.188475  0.482973
#
#      season_spring  season_summer  season_winter  ...  mnth_Oct  mnth_Sep  \
# 653          False          False           True  ...      True     False
# 576          False          False          False  ...     False     False
# 426           True          False          False  ...     False     False
# 728           True          False          False  ...     False     False
# 482          False           True          False  ...     False     False
#
#      weekday_Mon  weekday_Sat  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 653        False        False        False          False          True
# 576        False        False        False          False          True
# 426        False         True        False          False         False
# 728        False        False         True          False         False
# 482        False         True        False          False         False
#
#      weekday_Wed  weathersit_B  weathersit_C
# 653        False         False         False
# 576        False         False         False
# 426        False          True         False
# 728        False         False         False
# 482        False          True         False
#
# [5 rows x 29 columns]

# %%
np.array(x_train)
# Out:
# array([[1, 0, 1, ..., False, False, False],
#        [1, 0, 1, ..., False, False, False],
#        [1, 0, 0, ..., False, True, False],
#        ...,
#        [0, 0, 1, ..., True, False, False],
#        [0, 0, 0, ..., False, True, False],
#        [0, 0, 1, ..., False, True, False]], dtype=object)

# %%
import statsmodels.api as sm

# %%
x_train=x_train.astype(float)
y_train=y_train.astype(float)
x_train_lm = sm.add_constant(x_train)
lr = sm.OLS(y_train, x_train_lm).fit()

# %%
lr.params
# Out:
# const            0.000000e+00
# yr               4.928783e-16
# holiday         -1.637579e-15
# workingday      -9.237403e-17
# temp            -2.220446e-16
# hum             -2.775558e-16
# windspeed        8.049117e-16
# cnt              1.000000e+00
# season_spring   -2.914335e-16
# season_summer   -3.608225e-16
# season_winter    2.081668e-16
# mnth_Aug        -1.873501e-16
# mnth_Dec         1.734723e-17
# mnth_Feb        -2.359224e-16
# mnth_Jan         2.428613e-16
# mnth_Jul         8.326673e-17
# mnth_Jun         8.326673e-16
# mnth_Mar         2.437286e-16
# mnth_May         6.869505e-16
# mnth_Nov        -9.367507e-17
# mnth_Oct        -5.134781e-16
# mnth_Sep         1.526557e-16
# weekday_Mon      1.134509e-15
# weekday_Sat      0.000000e+00
# weekday_Sun     -6.245005e-17
# weekday_Thurs    4.024558e-16
# weekday_Tues     1.977585e-16
# weekday_Wed      3.608225e-16
# weathersit_B     3.582204e-16
# weathersit_C     5.416674e-16
# dtype: float64

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
print(lm.intercept_)
# Out:
# [ 5.90010615e-17 -8.32874772e-03 -8.32874772e-03 -5.55111512e-16
#   9.71445147e-17  7.02563008e-17  1.00000000e+00  1.52655666e-16
#  -1.52655666e-16 -5.55111512e-17 -1.52655666e-16 -1.38777878e-17
#   1.38777878e-17 -6.93889390e-18 -1.00613962e-16 -1.42247325e-16
#   2.09901541e-16 -1.52655666e-16 -6.93889390e-17 -1.45716772e-16
#  -1.73472348e-16  8.32667268e-17 -8.32874772e-03 -8.32874772e-03
#   1.24900090e-16  1.15467531e-16 -5.11743425e-17  1.45716772e-16
#   3.88578059e-16]
# 0.008328747723206908

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.140e+30
# Date:                Sat, 29 Jun 2024   Prob (F-statistic):               0.00
# Time:                        18:19:32   Log-Likelihood:                 17122.
# No. Observations:                 510   AIC:                        -3.419e+04
# Df Residuals:                     481   BIC:                        -3.406e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const                  0   2.74e-16          0      1.000   -5.38e-16    5.38e-16
# yr             4.929e-16   9.84e-17      5.008      0.000       3e-16    6.86e-16
# holiday       -1.638e-15   1.78e-16     -9.213      0.000   -1.99e-15   -1.29e-15
# workingday    -9.237e-17   9.65e-17     -0.958      0.339   -2.82e-16    9.71e-17
# temp           -2.22e-16   3.75e-16     -0.592      0.554   -9.59e-16    5.15e-16
# hum           -2.776e-16   2.89e-16     -0.959      0.338   -8.46e-16    2.91e-16
# windspeed      8.049e-16      2e-16      4.017      0.000    4.11e-16     1.2e-15
# cnt               1.0000   3.37e-16   2.96e+15      0.000       1.000       1.000
# season_spring -2.914e-16   2.22e-16     -1.310      0.191   -7.29e-16    1.46e-16
# season_summer -3.608e-16   1.94e-16     -1.856      0.064   -7.43e-16    2.12e-17
# season_winter  2.082e-16    2.1e-16      0.993      0.321   -2.04e-16     6.2e-16
# mnth_Aug      -1.874e-16   2.49e-16     -0.751      0.453   -6.77e-16    3.03e-16
# mnth_Dec       1.735e-17   2.49e-16      0.070      0.945   -4.72e-16    5.07e-16
# mnth_Feb      -2.359e-16   2.44e-16     -0.968      0.334   -7.15e-16    2.43e-16
# mnth_Jan       2.429e-16   2.49e-16      0.975      0.330   -2.47e-16    7.32e-16
# mnth_Jul       8.327e-17    2.6e-16      0.320      0.749   -4.27e-16    5.94e-16
# mnth_Jun       8.327e-16   1.86e-16      4.484      0.000    4.68e-16     1.2e-15
# mnth_Mar       2.437e-16   1.82e-16      1.342      0.180   -1.13e-16    6.01e-16
# mnth_May        6.87e-16   1.56e-16      4.412      0.000    3.81e-16    9.93e-16
# mnth_Nov      -9.368e-17   2.69e-16     -0.348      0.728   -6.23e-16    4.36e-16
# mnth_Oct      -5.135e-16   2.65e-16     -1.938      0.053   -1.03e-15    7.12e-18
# mnth_Sep       1.527e-16   2.39e-16      0.640      0.522   -3.16e-16    6.21e-16
# weekday_Mon    1.135e-15   1.14e-16      9.989      0.000    9.11e-16    1.36e-15
# weekday_Sat            0   1.07e-16          0      1.000   -2.09e-16    2.09e-16
# weekday_Sun   -6.245e-17   1.04e-16     -0.600      0.549   -2.67e-16    1.42e-16
# weekday_Thurs  4.025e-16   1.15e-16      3.503      0.001    1.77e-16    6.28e-16
# weekday_Tues   1.978e-16   1.15e-16      1.721      0.086    -2.8e-17    4.24e-16
# weekday_Wed    3.608e-16    1.1e-16      3.272      0.001    1.44e-16    5.78e-16
# weathersit_B   3.582e-16   7.99e-17      4.481      0.000    2.01e-16    5.15e-16
# weathersit_C   5.417e-16   2.13e-16      2.538      0.011    1.22e-16    9.61e-16
# ==============================================================================
# Omnibus:                       19.600   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.639
# Skew:                          -0.433   Prob(JB):                     2.00e-05
# Kurtosis:                       3.519   Cond. No.                     1.27e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.07e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# import rfe
from sklearn.feature_selection import RFE

# %%
lm=LinearRegression()
rfe1 = RFE(estimator=lm, n_features_to_select=15)

# fit with 15 feature
rfe1.fit(x_train,y_train)
print(rfe1.support_)
print(rfe1.ranking_)
# Out:
# [ True  True  True False  True False  True False False False  True  True
#  False False False  True  True False  True  True False False  True  True
#  False  True False False  True]
# [ 1  1  1  2  1 10  1 14  5  3  1  1 12 15  7  1  1 13  1  1  6 11  1  1
#   9  1  8  4  1]

# %%
col1=x_train.columns[rfe1.support_]

# %%
col1
# Out:
# Index(['yr', 'holiday', 'workingday', 'hum', 'cnt', 'mnth_Aug', 'mnth_Dec',
#        'mnth_Jun', 'mnth_Mar', 'mnth_Nov', 'mnth_Oct', 'weekday_Sat',
#        'weekday_Sun', 'weekday_Tues', 'weathersit_C'],
#       dtype='object')

# %%
x_train_rfe1=x_train[col1]

x_train_rfe1=sm.add_constant(x_train_rfe1)
lm1=sm.OLS(y_train,x_train_rfe1).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.587e+29
# Date:                Sat, 29 Jun 2024   Prob (F-statistic):               0.00
# Time:                        18:19:33   Log-Likelihood:                 16674.
# No. Observations:                 510   AIC:                        -3.332e+04
# Df Residuals:                     495   BIC:                        -3.325e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -6.176e-16   3.09e-16     -2.000      0.046   -1.22e-15   -1.09e-17
# yr            8.934e-17   1.77e-16      0.504      0.615   -2.59e-16    4.38e-16
# holiday       3.608e-16   3.58e-16      1.009      0.314   -3.42e-16    1.06e-15
# workingday   -1.051e-15   1.54e-16     -6.834      0.000   -1.35e-15   -7.49e-16
# hum          -7.216e-16   5.01e-16     -1.442      0.150   -1.71e-15    2.62e-16
# cnt              1.0000   4.35e-16    2.3e+15      0.000       1.000       1.000
# mnth_Aug     -2.359e-16   2.53e-16     -0.933      0.351   -7.33e-16    2.61e-16
# mnth_Dec     -5.551e-17   2.61e-16     -0.213      0.831   -5.67e-16    4.56e-16
# mnth_Jun      6.939e-17   2.81e-16      0.247      0.805   -4.83e-16    6.22e-16
# mnth_Mar      2.394e-16   2.45e-16      0.976      0.330   -2.43e-16    7.22e-16
# mnth_Nov      1.457e-16   2.57e-16      0.568      0.570   -3.59e-16     6.5e-16
# mnth_Oct     -3.261e-16   2.64e-16     -1.236      0.217   -8.45e-16    1.92e-16
# weekday_Sat  -6.661e-16   1.88e-16     -3.546      0.000   -1.04e-15   -2.97e-16
# weekday_Sun  -7.364e-16   1.91e-16     -3.857      0.000   -1.11e-15   -3.61e-16
# weekday_Tues  1.561e-16   2.13e-16      0.735      0.463   -2.61e-16    5.74e-16
# weathersit_C  2.108e-16   4.42e-16      0.477      0.634   -6.58e-16    1.08e-15
# ==============================================================================
# Omnibus:                       71.281   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.979
# Skew:                          -0.807   Prob(JB):                     1.80e-30
# Kurtosis:                       4.960   Cond. No.                     2.16e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.85e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
a = x_train_rfe1.drop('const', axis=1)

# %%
vif = pd.DataFrame()
vif['features'] = a.columns
vif['VIF'] = [variance_inflation_factor(a.values, i) for i in range(a.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#         features    VIF
# 2     workingday  21.68
# 11   weekday_Sat   5.44
# 12   weekday_Sun   5.12
# 4            cnt   2.01
# 0             yr   1.66
# 1        holiday   1.65
# 14  weathersit_C   1.18
# 5       mnth_Aug   1.17
# 10      mnth_Oct   1.16
# 7       mnth_Jun   1.15
# 3            hum   1.12
# 8       mnth_Mar   1.12
# 6       mnth_Dec   1.11
# 9       mnth_Nov   1.10
# 13  weekday_Tues   1.09

# %%
lm=LinearRegression()
rfe2 = RFE(estimator=lm, n_features_to_select=7)

# fit with  feature
rfe2.fit(x_train,y_train)
print(rfe2.support_)
print(rfe2.ranking_)
# Out:
# [False  True  True False False False  True False False False False  True
#  False False False  True False False False False False False  True  True
#  False False False False False]
# [ 7  1  1 10  2 18  1 22 13 11  4  1 20 23 15  1  9 21  8  6 14 19  1  1
#  17  3 16 12  5]

# %%
col2=x_train.columns[rfe2.support_]

x_train_rfe2=x_train[col2]

x_train_rfe2=sm.add_constant(x_train_rfe2)
lm2=sm.OLS(y_train,x_train_rfe2).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.239e+31
# Date:                Sat, 29 Jun 2024   Prob (F-statistic):               0.00
# Time:                        18:19:33   Log-Likelihood:                 17317.
# No. Observations:                 510   AIC:                        -3.462e+04
# Df Residuals:                     503   BIC:                        -3.459e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.435e-16   4.47e-17     -3.215      0.001   -2.31e-16   -5.58e-17
# holiday      6.349e-16   9.82e-17      6.465      0.000    4.42e-16    8.28e-16
# workingday  -3.123e-16   3.63e-17     -8.598      0.000   -3.84e-16   -2.41e-16
# cnt             1.0000   8.92e-17   1.12e+16      0.000       1.000       1.000
# mnth_Dec    -3.816e-17   7.06e-17     -0.541      0.589   -1.77e-16    1.01e-16
# mnth_Jun    -4.857e-16   7.52e-17     -6.455      0.000   -6.34e-16   -3.38e-16
# weekday_Sat  1.318e-16   4.91e-17      2.688      0.007    3.55e-17    2.28e-16
# weekday_Sun -1.318e-16   4.96e-17     -2.656      0.008   -2.29e-16   -3.43e-17
# ==============================================================================
# Omnibus:                       97.173   Durbin-Watson:                   0.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.504
# Skew:                          -0.938   Prob(JB):                     7.35e-57
# Kurtosis:                       5.940   Cond. No.                     9.90e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.54e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
b = x_train_rfe2.drop('const', axis=1)
vif1 = pd.DataFrame()
vif1['features'] = b.columns
vif1['VIF'] = [variance_inflation_factor(b.values, i) for i in range(b.shape[1])]
vif1['VIF'] = round(vif1['VIF'], 2)
vif1=vif1.sort_values(by="VIF",ascending=False)
vif1
# Out:
#       features   VIF
# 1   workingday  5.08
# 5  weekday_Sat  1.88
# 6  weekday_Sun  1.72
# 0      holiday  1.08
# 2          cnt  1.07
# 4     mnth_Jun  1.04
# 3     mnth_Dec  1.03

# %%
y_train_cnt=lm2.predict(x_train_rfe2)

# %%
fig=plt.figure()
sns.distplot((y_train,y_train_cnt),bins=20)
# Out:
# <Axes: ylabel='Density'>

# %%
df_test[var]=scaler.transform(df_test[var])
df_test
# Out:
#      yr  holiday  workingday      temp       hum  windspeed    casual  \
# 184   0        1           0  0.831783  0.657364   0.084219  0.933557
# 535   1        0           1  0.901354  0.610133   0.153728  0.265163
# 299   0        0           1  0.511964  0.837699   0.334206  0.072539
# 221   0        0           1  0.881625  0.437098   0.339570  0.268820
# 152   0        0           1  0.817246  0.314298   0.537414  0.223712
# ..   ..      ...         ...       ...       ...        ...       ...
# 400   1        0           0  0.257562  0.708888   0.287411  0.096312
# 702   1        0           1  0.519232  0.756118   0.283397  0.167327
# 127   0        0           0  0.584649  0.650923   0.069510  0.426394
# 640   1        0           1  0.745598  0.817947   0.052115  0.221274
# 72    0        0           1  0.331557  0.512107   0.203418  0.108808
#
#      registered       cnt  season_spring  ...  mnth_Oct  mnth_Sep  \
# 184    0.427086  0.692706          False  ...     False     False
# 535    0.767976  0.712034          False  ...     False     False
# 299    0.346376  0.303382          False  ...      True     False
# 221    0.559630  0.547400          False  ...     False     False
# 152    0.608143  0.569029          False  ...     False     False
# ..          ...       ...            ...  ...       ...       ...
# 400    0.376697  0.336516           True  ...     False     False
# 702    0.871354  0.757478          False  ...     False     False
# 127    0.420445  0.495973          False  ...     False     False
# 640    0.985273  0.868615          False  ...      True     False
# 72     0.240687  0.232858           True  ...     False     False
#
#      weekday_Mon  weekday_Sat  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 184         True        False        False          False         False
# 535        False        False        False          False         False
# 299        False        False        False           True         False
# 221        False        False        False          False         False
# 152        False        False        False           True         False
# ..           ...          ...          ...            ...           ...
# 400        False        False         True          False         False
# 702        False        False        False          False          True
# 127        False        False         True          False         False
# 640        False        False        False          False         False
# 72          True        False        False          False         False
#
#      weekday_Wed  weathersit_B  weathersit_C
# 184        False          True         False
# 535         True         False         False
# 299        False          True         False
# 221         True         False         False
# 152        False         False         False
# ..           ...           ...           ...
# 400        False          True         False
# 702        False         False         False
# 127        False         False         False
# 640         True          True         False
# 72         False         False         False
#
# [219 rows x 31 columns]

# %%
y_test=df_test.pop('cnt')
x_test=df_test.drop(["casual","registered"],axis=1)

# %%
x_test.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed  season_spring  \
# 184   0        1           0  0.831783  0.657364   0.084219          False
# 535   1        0           1  0.901354  0.610133   0.153728          False
# 299   0        0           1  0.511964  0.837699   0.334206          False
# 221   0        0           1  0.881625  0.437098   0.339570          False
# 152   0        0           1  0.817246  0.314298   0.537414          False
#
#      season_summer  season_winter  mnth_Aug  ...  mnth_Oct  mnth_Sep  \
# 184          False          False     False  ...     False     False
# 535           True          False     False  ...     False     False
# 299          False           True     False  ...      True     False
# 221          False          False      True  ...     False     False
# 152           True          False     False  ...     False     False
#
#      weekday_Mon  weekday_Sat  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 184         True        False        False          False         False
# 535        False        False        False          False         False
# 299        False        False        False           True         False
# 221        False        False        False          False         False
# 152        False        False        False           True         False
#
#      weekday_Wed  weathersit_B  weathersit_C
# 184        False          True         False
# 535         True         False         False
# 299        False          True         False
# 221         True         False         False
# 152        False         False         False
#
# [5 rows x 28 columns]

# %%
c=x_train_rfe2.drop('const',axis=1)

# %%
c
# Out:
#      holiday  workingday       cnt  mnth_Dec  mnth_Jun  weekday_Sat  \
# 653      0.0         1.0  0.864243       0.0       0.0          0.0
# 576      0.0         1.0  0.827658       0.0       0.0          0.0
# 426      0.0         0.0  0.465255       0.0       0.0          1.0
# 728      0.0         0.0  0.204096       1.0       0.0          0.0
# 482      0.0         0.0  0.482973       0.0       0.0          1.0
# ..       ...         ...       ...       ...       ...          ...
# 526      0.0         1.0  0.764151       0.0       1.0          0.0
# 578      0.0         1.0  0.832835       0.0       0.0          0.0
# 53       0.0         1.0  0.218017       0.0       0.0          0.0
# 350      0.0         0.0  0.312586       1.0       0.0          1.0
# 79       0.0         1.0  0.236424       0.0       0.0          0.0
#
#      weekday_Sun
# 653          0.0
# 576          0.0
# 426          0.0
# 728          1.0
# 482          0.0
# ..           ...
# 526          0.0
# 578          0.0
# 53           0.0
# 350          0.0
# 79           0.0
#
# [510 rows x 7 columns]

# %%
col2=c.columns

# %%
existing_columns = [col for col in col2 if col in x_test.columns]

# If any columns are missing, print a warning
missing_columns = [col for col in col2 if col not in x_test.columns]

# Select the existing columns from x_test
x_test_rfe2 = x_test[existing_columns]

# %%
x_test_rfe2 = sm.add_constant(x_test_rfe2)

# %%
x_test_rfe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 184 to 72
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   const        219 non-null    float64
#  1   holiday      219 non-null    int64
#  2   workingday   219 non-null    int64
#  3   mnth_Dec     219 non-null    bool
#  4   mnth_Jun     219 non-null    bool
#  5   weekday_Sat  219 non-null    bool
#  6   weekday_Sun  219 non-null    bool
# dtypes: bool(4), float64(1), int64(2)
# memory usage: 7.7 KB

# %%
# Identify the exact columns used to train the model
train_columns = lm2.model.exog_names

# Align the test data columns with the training data columns
x_test_rfe2_aligned = x_test_rfe2.reindex(columns=train_columns, fill_value=0)

# Predict using the aligned test data
y_pred = lm2.predict(x_test_rfe2_aligned)

# %%
plt.figure()
plt.scatter(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -5.706094293306386

# %%
plt.figure(figsize=(8,5))
sns.heatmap(dataset[col2].corr(), cmap='YlGnBu', annot=True)
plt.show()
